# %%
import pandas as pd

# %% [markdown]
# ```bash
# pip install sqlalchemy psycopg2-binary
# ```

# %%
pip install sqlalchemy psycopg2-binary
# Out:
# ...
#      ---------------------------------------- 1.6/1.6 MB 5.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 6.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 190.9/190.9 kB 5.8 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://samkonsadmin:sampostgres.postgres.database.azure.com:5432/ny_taxi')

# %%
def get_engine(database=dbName, username=dbUser, password=dbPass, host=dbHost, port=5432):
    engine_string = f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
    engine = create_engine(engine_string)
    print("Database connection done!")
    return engine

# %%
get_engine('postgres', 'samkonsadmin','$4mkonS1991','92.73.53.86')
# Out:
# Database connection done!
# Engine(postgresql+psycopg2://samkonsadmin:***@92.73.53.86:5432/postgres)

# %%
database='postgres' 
username='postgres' 
password='$4mkonS1991'
host='localhost'
port=5432
engine_string = f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(engine_string)
print("Database connection done!")
# Out:
# Database connection done!

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='test'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\THINKP~1\AppData\Local\Temp/ipykernel_4364/2228592315.py in <module>
# ----> 1 print(pd.io.sql.get_schema(df, name='test'))
#
# NameError: name 'df' is not defined

# %%
password='$4mkonS1991'
database='sampostgres'
conn = psycopg2.connect(host='sampostgres.postgres.database.azure.com', port=5432, dbname={database}, user='samkonsadmin', password={password}, sslmode='require')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\Users\THINKP~1\AppData\Local\Temp/ipykernel_12320/1036747802.py in <module>
#       1 password='$4mkonS1991'
#       2 database='sampostgres'
# ----> 3 conn = psycopg2.connect(host='sampostgres.postgres.database.azure.com', port=5432, dbname={database}, user='samkonsadmin', password={password}, sslmode='require')
#
# C:\Python310\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# ...

# %%
query = """
SELECT * from postgres;
"""

pd.read_sql(query, con=engine)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# C:\Python310\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899                 if not evt_handled:
# -> 1900                     self.dialect.do_execute(
#    1901                         cursor, statement, parameters, context
#
# C:\Python310\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     735     def do_execute(self, cursor, statement, parameters, context=None):
# --> 736         cursor.execute(statement, parameters)
#     737
#
# UndefinedTable: relation "postgres" does not exist
# LINE 2: SELECT * from postgres;
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df.to_sql(name='yellow_tripdata_trip', con=engine, index=False)

# %%
query = """
SELECT * FROM yellow_tripdata_trip LIMIT 10
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# 5         1  2021-01-01 00:16:29   2021-01-01 00:24:30                1
# 6         1  2021-01-01 00:00:28   2021-01-01 00:17:28                1
# 7         1  2021-01-01 00:12:29   2021-01-01 00:30:34                1
# 8         1  2021-01-01 00:39:16   2021-01-01 01:00:13                1
# 9         1  2021-01-01 00:26:12   2021-01-01 00:39:46                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# ...

# %% [markdown]
# ```sql
# SELECT *
# FROM pg_catalog.pg_tables
# WHERE schemaname != 'pg_catalog' AND
#     schemaname != 'information_schema';
# ```
#
# Source: https://www.postgresqltutorial.com/postgresql-show-tables/
